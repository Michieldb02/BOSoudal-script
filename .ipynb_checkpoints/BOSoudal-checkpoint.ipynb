# %%
import geopandas as gpd
fp = 'C:/Users/michi/Documents/Blok 2 Jaar 4/' 
gdf = gpd.read_file("Soudal_location.csv")
gdf = gpd.GeoDataFrame(gdf, geometry=gpd.points_from_xy(gdf['x-coordinate'], gdf['y-coordinate']))
gdf.crs = 'epsg:4326'
display(gdf)
# Out:
# C:\Users\michi\miniconda3\lib\site-packages\geopandas\_compat.py:106: UserWarning: The Shapely GEOS version (3.11.3-CAPI-1.17.3) is incompatible with the GEOS version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(
#     ID   Country             City       Plant type  ZIP code Receiving_plant  \
# 0    1  Portugal         Lissabon  Receiving plant  2710-207            2200
# 1    2     Spain          Alovera  Receiving plant     19208            1900
# 2    3     Italy  Cologno Monzese  Receiving plant     20093            2000
# 3    4    France            Blyes  Receiving plant      1150            1800
# 4    5   Belgium         Turnhout  Producing plant      2300            2300
# 5    6    Latvia           Dobele  Producing plant      3701            3701
# 6    7    Poland           Pionki  Producing plant    26-670          26-670
# 7    8  Portugal         Lissabon  Producing plant  2710-207            2200
# 8    9  Slovenia         Srpenica  Producing plant      5224            5224
# 9   10     Spain          Alovera  Producing plant     19208            1900
# 10  12    Turkey  Tuzla, Istanbul  Producing plant     34956           34956
#
#     x-coordinate y-coordinate                   geometry
# 0      -9.369216    38.757301  POINT (-9.36922 38.75730)
# 1   -3.243162431  40.57675934  POINT (-3.24316 40.57676)
# 2    9.281575673  45.54113003   POINT (9.28158 45.54113)
# 3    5.261173337  45.83747369   POINT (5.26117 45.83747)
# 4    4.928540898  51.29525785   POINT (4.92854 51.29526)
# 5    23.30237845  56.62518423  POINT (23.30238 56.62518)
# 6    21.45811508  51.46902482  POINT (21.45812 51.46902)
# 7      -9.369216    38.757301  POINT (-9.36922 38.75730)
# 8     13.5166732  46.28409136  POINT (13.51667 46.28409)
# 9   -3.243162431  40.57675934  POINT (-3.24316 40.57676)
# 10   29.36691489   40.8858807  POINT (29.36691 40.88588)

# %%
import pandas as pd
df = pd.read_csv("C:/Users/michi/Documents/Blok 2 Jaar 4/Postal_points_csv.csv")
df = df.set_index('fid')
df = df.drop_duplicates(subset=['postalcodes'])
display(df)
df2 = pd.read_csv("C:/Users/michi/Documents/Blok 2 Jaar 4/Customers_orders 1.csv", sep=',')
df2 = df2.set_index('fid')
df2 = df2.drop_duplicates(subset=['postalcodes'])
display(df2)
# Out:
#        POSTCODE CNTR_ID postalcodes          x          y
# fid
# 1          1074      DK     DK_1074  12.583633  55.679565
# 2          1111      DK     DK_1111  12.580963  55.681969
# 3          1115      DK     DK_1115  12.578370  55.681033
# 4          1120      DK     DK_1120  12.578612  55.682419
# 5          1122      DK     DK_1122  12.579583  55.682525
# ...         ...     ...         ...        ...        ...
# 808419   768 05      CZ   CZ_768 05  17.185137  49.139282
# 808420   793 44      CZ   CZ_793 44  17.200060  49.899448
# 808421   793 51      CZ   CZ_793 51  17.310940  49.861829
# 808422   794 01      CZ   CZ_794 01  17.700822  50.085110
# 808423   793 82      CZ   CZ_793 82  17.574787  50.201454
#
# [808423 rows x 5 columns]
#         Plant  Quantity_Delivered Customer_ZIP Customer_Country  postalcodes
# fid
# 1        2000                  24        20091               IT     IT_20091
# 2        2200                  16     2530-094               PT  PT_2530-094
# 3        1800                   2        34540               FR     FR_34540
# 4        1800                   1        84120               FR     FR_84120
# 5        2200                  12     3885-809               PT  PT_3885-809
# ...       ...                 ...          ...              ...          ...
# 797624   2200                   2     3680-142               PT  PT_3680-142
# 798478   2200                   2     2460-302               PT  PT_2460-302
# 799959   2200                   1     2800-260               PT  PT_2800-260
# 805818   2200                   5     2750-074               PT  PT_2750-074
# 808636   2200                   3     5225-032               PT  PT_5225-032
#
# [3832 rows x 5 columns]

# %%
df.postalcodes.astype(str)
df2.postalcodes.astype(str)
finaldf = pd.merge(df, df2, on='postalcodes')
display(finaldf)
finaldf.to_csv("C:/Users/michi/Documents/Blok 2 Jaar 4/customers.csv")
# Out:
#      POSTCODE CNTR_ID postalcodes          x          y  Plant  \
# 0       16153      IT    IT_16153   8.856824  44.433111   2000
# 1       16038      IT    IT_16038   9.205905  44.333659   2000
# 2       47043      IT    IT_47043  12.400370  44.135109   2000
# 3       12045      IT    IT_12045   7.724159  44.551239   2000
# 4       12012      IT    IT_12012   7.553786  44.328486   2000
# ...       ...     ...         ...        ...        ...    ...
# 3386     8398      ES     ES_8398   2.710937  41.640498   1900
# 3387     9199      ES     ES_9199  -3.483225  42.334887   1900
# 3388     9240      ES     ES_9240  -3.325379  42.550646   1900
# 3389     9200      ES     ES_9200  -2.943871  42.684953   1900
# 3390     9120      ES     ES_9120  -4.009012  42.516175   1900
#
#       Quantity_Delivered Customer_ZIP Customer_Country
# 0                     84        16153               IT
# 1                     24        16038               IT
# 2                    120        47043               IT
# 3                     12        12045               IT
# 4                      0        12012               IT
# ...                  ...          ...              ...
# 3386                  12         8398               ES
# 3387                   6         9199               ES
# 3388                 120         9240               ES
# 3389                  48         9200               ES
# 3390                  12         9120               ES
#
# [3391 rows x 9 columns]
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Input In [4], in <cell line: 5>()
#       3 finaldf = pd.merge(df, df2, on='postalcodes')
#       4 display(finaldf)
# ----> 5 finaldf.to_csv("C:/Users/michi/Documents/Blok 2 Jaar 4/customers.csv")
#
# File ~\miniconda3\lib\site-packages\pandas\core\generic.py:3551, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3540 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3542 formatter = DataFrameFormatter(
#    3543     frame=df,
#    3544     header=header,
#    (...)
#    3548     decimal=decimal,
#    3549 )
# -> 3551 return DataFrameRenderer(formatter).to_csv(
#    3552     path_or_buf,
#    3553     line_terminator=line_terminator,
#    3554     sep=sep,
#    3555     encoding=encoding,
#    3556     errors=errors,
#    3557     compression=compression,
#    3558     quoting=quoting,
#    3559     columns=columns,
#    3560     index_label=index_label,
#    3561     mode=mode,
#    3562     chunksize=chunksize,
#    3563     quotechar=quotechar,
#    3564     date_format=date_format,
#    3565     doublequote=doublequote,
#    3566     escapechar=escapechar,
#    3567     storage_options=storage_options,
#    3568 )
#
# File ~\miniconda3\lib\site-packages\pandas\io\formats\format.py:1180, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1159     created_buffer = False
#    1161 csv_formatter = CSVFormatter(
#    1162     path_or_buf=path_or_buf,
#    1163     line_terminator=line_terminator,
#    (...)
#    1178     formatter=self.fmt,
#    1179 )
# -> 1180 csv_formatter.save()
#    1182 if created_buffer:
#    1183     assert isinstance(path_or_buf, StringIO)
#
# File ~\miniconda3\lib\site-packages\pandas\io\formats\csvs.py:241, in CSVFormatter.save(self)
#     237 """
#     238 Create the writer & save.
#     239 """
#     240 # apply compression and byte/text conversion
# --> 241 with get_handle(
#     242     self.filepath_or_buffer,
#     243     self.mode,
#     244     encoding=self.encoding,
#     245     errors=self.errors,
#     246     compression=self.compression,
#     247     storage_options=self.storage_options,
#     248 ) as handles:
#     249
#     250     # Note: self.encoding is irrelevant here
#     251     self.writer = csvlib.writer(
#     252         handles.handle,
#     253         lineterminator=self.line_terminator,
#    (...)
#     258         quotechar=self.quotechar,
#     259     )
#     261     self._save()
#
# File ~\miniconda3\lib\site-packages\pandas\io\common.py:786, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     781 elif isinstance(handle, str):
#     782     # Check whether the filename is to be opened in binary mode.
#     783     # Binary mode does not support 'encoding' and 'newline'.
#     784     if ioargs.encoding and "b" not in ioargs.mode:
#     785         # Encoding
# --> 786         handle = open(
#     787             handle,
#     788             ioargs.mode,
#     789             encoding=ioargs.encoding,
#     790             errors=errors,
#     791             newline="",
#     792         )
#     793     else:
#     794         # Binary mode
#     795         handle = open(handle, ioargs.mode)
#
# PermissionError: [Errno 13] Permission denied: 'C:/Users/michi/Documents/Blok 2 Jaar 4/customers.csv'

# %%
import folium
m = folium.Map(location=[20, 0], zoom_start=3, height=500)
for i in range(len(gdf)):
    popup_content = f"<b>{gdf.iloc[i]['City']}</b>:<br>{gdf.iloc[i]['Plant type']}"
    folium.Marker(location=[gdf.iloc[i]['y-coordinate'], gdf.iloc[i]['x-coordinate']], popup=popup_content).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_649aa1c78c885eb10472b0e44f583a16 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 500.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_649aa1c78c885eb10472b0e44f583a16&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_649aa1c78c885eb10472b0e44f583a16 = L.map(
#                 &quot;map_649aa1c78c885eb10472b0e44f583a16&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_22c6ce8457fe5ab60aca912aeb09f633 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_22c6ce8457fe5ab60aca912aeb09f633.addTo(map_649aa1c78c885eb10472b0e44f583a16);
#
#
#             var marker_de7d0a2f838b1009cfe2d52a11e53fcf = L.marker(
#                 [38.757301, -9.369216],
#                 {}
#             ).addTo(map_649aa1c78c885eb10472b0e44f583a16);
#
#
#         var popup_162c767cf5708027ac4a22063c90089f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6513ddbaa5c515e6c4ad7f52c62e2cc8 = $(`&lt;div id=&quot;html_6513ddbaa5c515e6c4ad7f52c62e2cc8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Lissabon&lt;/b&gt;:&lt;br&gt;Receiving plant&lt;/div&gt;`)[0];
#                 popup_162c767cf5708027ac4a22063c90089f.setContent(html_6513ddbaa5c515e6c4ad7f52c62e2cc8);
#
#
#
#         marker_de7d0a2f838b1009cfe2d52a11e53fcf.bindPopup(popup_162c767cf5708027ac4a22063c90089f)
#         ;
#
#
#
#
#             var marker_31e81c6a1ee2f4e51c1f26acd639d106 = L.marker(
#                 [40.57675934, -3.243162431],
#                 {}
#             ).addTo(map_649aa1c78c885eb10472b0e44f583a16);
#
#
#         var popup_c45d902c42ad18c7dc73341852190a35 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_026db887e475d6a9c0b410436a418dfa = $(`&lt;div id=&quot;html_026db887e475d6a9c0b410436a418dfa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Alovera&lt;/b&gt;:&lt;br&gt;Receiving plant&lt;/div&gt;`)[0];
#                 popup_c45d902c42ad18c7dc73341852190a35.setContent(html_026db887e475d6a9c0b410436a418dfa);
#
#
#
#         marker_31e81c6a1ee2f4e51c1f26acd639d106.bindPopup(popup_c45d902c42ad18c7dc73341852190a35)
#         ;
#
#
#
#
#             var marker_71713f0c00e6dcb7b7d10e398fa42728 = L.marker(
#                 [45.54113003, 9.281575673],
#                 {}
#             ).addTo(map_649aa1c78c885eb10472b0e44f583a16);
#
#
#         var popup_8cac2e0bb1805d70d3127daf75f42194 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_18552d27dc9bb3471bf1ced8857bda3e = $(`&lt;div id=&quot;html_18552d27dc9bb3471bf1ced8857bda3e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Cologno Monzese&lt;/b&gt;:&lt;br&gt;Receiving plant&lt;/div&gt;`)[0];
#                 popup_8cac2e0bb1805d70d3127daf75f42194.setContent(html_18552d27dc9bb3471bf1ced8857bda3e);
#
#
#
#         marker_71713f0c00e6dcb7b7d10e398fa42728.bindPopup(popup_8cac2e0bb1805d70d3127daf75f42194)
#         ;
#
#
#
#
#             var marker_e29c34d512f2da65a332c6b75f6ad047 = L.marker(
#                 [45.83747369, 5.261173337],
#                 {}
#             ).addTo(map_649aa1c78c885eb10472b0e44f583a16);
#
#
#         var popup_4b9dab0aebfb44d54b4e7fd2529b5a77 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_761b2794dd3dcfae82a985a4e4876144 = $(`&lt;div id=&quot;html_761b2794dd3dcfae82a985a4e4876144&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Blyes&lt;/b&gt;:&lt;br&gt;Receiving plant&lt;/div&gt;`)[0];
#                 popup_4b9dab0aebfb44d54b4e7fd2529b5a77.setContent(html_761b2794dd3dcfae82a985a4e4876144);
#
#
#
#         marker_e29c34d512f2da65a332c6b75f6ad047.bindPopup(popup_4b9dab0aebfb44d54b4e7fd2529b5a77)
#         ;
#
#
#
#
#             var marker_c988567df62f2950daa19c49e62f08fe = L.marker(
#                 [51.29525785, 4.928540898],
#                 {}
#             ).addTo(map_649aa1c78c885eb10472b0e44f583a16);
#
#
#         var popup_f99ae34ad6d992825b4bd78025577c54 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5f6f9d897da19f457c6226a70025795b = $(`&lt;div id=&quot;html_5f6f9d897da19f457c6226a70025795b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Turnhout&lt;/b&gt;:&lt;br&gt;Producing plant&lt;/div&gt;`)[0];
#                 popup_f99ae34ad6d992825b4bd78025577c54.setContent(html_5f6f9d897da19f457c6226a70025795b);
#
#
#
#         marker_c988567df62f2950daa19c49e62f08fe.bindPopup(popup_f99ae34ad6d992825b4bd78025577c54)
#         ;

# %%
# data from unemployement and household income is from 2019!!!

# Script for rasterizing vector datasets

# import pandas as pd
# from geocube.api.core import make_geocube
# from geocube.rasterize import rasterize_image
# from functools import partial
# from rasterio.enums import MergeAlg


# hhi = gpd.read_file(f"{fp}/landprices.gpkg")
# hhi = hhi.to_crs('EPSG:3035')
# final_raster = make_geocube(
# vector_data=hhi,
# measurements=["valuefinal"],
# resolution=(-500, 500),
# fill = 0)
    
# final_raster.rio.to_raster('C:/Users/michi/Documents/Blok 2 Jaar 4/final_landvalue.tif')

# %%
# Script for retrieving x data from y region/country

# import osmnx as ox
# cf = '["highway" ~"motorway"]' 
# # ~"trunk"
# G = ox.graph_from_place('Hungary', simplify=True, custom_filter=cf)
# gdfhighways = ox.graph_to_gdfs(G, nodes=False)
# gdfhighways = gdfhighways.drop(columns=['osmid', 'lanes', 'maxspeed', 'oneway', 'ref', 'name', 'highway', 'reversed', 'length', 'bridge'])
# gdfhighways['id'] = range(len(gdfhighways))
# gdfhighways = gdfhighways.set_index('id')
# display(gdfhighways)
# gdfhighways.plot()
# type(gdfhighways)
# gdfhighways.to_file("C:/Users/michi/Documents/Blok 2 Jaar 4/highway networks/highwayshungary.gpkg", driver="GPKG")

# %%
# import pandas as pd

# # Read the CSV file containing education data into a DataFrame
# df_edu = pd.read_csv("Education2022.csv")

# # Drop rows with missing values
# df_edu.dropna(subset=['...2'], inplace=True)  # Replace '...2' with the actual column name

# # Rename columns
# df_edu.rename(columns={'...2': 'Percentage'}, inplace=True)  # Replace '...2' with the actual column name

# # Round min and max values
# min_value = round(df_edu['Percentage'].min())
# max_value = round(df_edu['Percentage'].max())

# # Define the number of bins
# num_bins = 5

# # Calculate bin width
# bin_width = (max_value - min_value) / num_bins

# # Define the custom bin boundaries
# custom_bin_boundaries = [round(min_value + i * bin_width) for i in range(num_bins + 1)]

# # Cut the data into custom ranges
# df_edu['Custom_bin'] = pd.cut(df_edu['Percentage'], bins=custom_bin_boundaries, include_lowest=True)

# # Count the frequency of values falling into each custom bin
# custom_bin_counts = df_edu['Custom_bin'].value_counts().sort_index()

# # Print the counts for each custom range
# for index, count in custom_bin_counts.items():
#     print(f"Frequency for range {index}: {count}")
