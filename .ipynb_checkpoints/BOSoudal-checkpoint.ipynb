# %%
import geopandas as gpd
fp = 'C:/Users/michi/Documents/Blok 2 Jaar 4/' 
gdf = gpd.read_file(f"{fp}Soudal_location.csv")
gdf = gpd.GeoDataFrame(gdf, geometry=gpd.points_from_xy(gdf['x-coordinate'], gdf['y-coordinate']))
gdf.crs = 'epsg:4326'
display(gdf)
# Out:
#     ID   Country             City       Plant type  ZIP code Receiving_plant  \
# 0    1  Portugal         Lissabon  Receiving plant  2710-207            2200
# 1    2     Spain          Alovera  Receiving plant     19208            1900
# 2    3     Italy  Cologno Monzese  Receiving plant     20093            2000
# 3    4    France            Blyes  Receiving plant      1150            1800
# 4    5   Belgium         Turnhout  Producing plant      2300            2300
# 5    6    Latvia           Dobele  Producing plant      3701            3701
# 6    7    Poland           Pionki  Producing plant    26-670          26-670
# 7    8  Portugal         Lissabon  Producing plant  2710-207            2200
# 8    9  Slovenia         Srpenica  Producing plant      5224            5224
# 9   10     Spain          Alovera  Producing plant     19208            1900
# 10  12    Turkey  Tuzla, Istanbul  Producing plant     34956           34956
#
#     x-coordinate y-coordinate                   geometry
# 0      -9.369216    38.757301  POINT (-9.36922 38.75730)
# 1   -3.243162431  40.57675934  POINT (-3.24316 40.57676)
# 2    9.281575673  45.54113003   POINT (9.28158 45.54113)
# 3    5.261173337  45.83747369   POINT (5.26117 45.83747)
# 4    4.928540898  51.29525785   POINT (4.92854 51.29526)
# 5    23.30237845  56.62518423  POINT (23.30238 56.62518)
# 6    21.45811508  51.46902482  POINT (21.45812 51.46902)
# 7      -9.369216    38.757301  POINT (-9.36922 38.75730)
# 8     13.5166732  46.28409136  POINT (13.51667 46.28409)
# 9   -3.243162431  40.57675934  POINT (-3.24316 40.57676)
# 10   29.36691489   40.8858807  POINT (29.36691 40.88588)

# %%
import folium
m = folium.Map(location=[20, 0], zoom_start=3, height=500)
for i in range(len(gdf)):
    popup_content = f"<b>{gdf.iloc[i]['City']}</b>:<br>{gdf.iloc[i]['Plant type']}"
    folium.Marker(location=[gdf.iloc[i]['y-coordinate'], gdf.iloc[i]['x-coordinate']], popup=popup_content).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5acb907c044326aad1c77b0b4523035a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 500.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5acb907c044326aad1c77b0b4523035a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5acb907c044326aad1c77b0b4523035a = L.map(
#                 &quot;map_5acb907c044326aad1c77b0b4523035a&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d6beda4b89d724085a4de6fdc7d8061c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d6beda4b89d724085a4de6fdc7d8061c.addTo(map_5acb907c044326aad1c77b0b4523035a);
#
#
#             var marker_bff19858cbed71f5efbf0bd966521f8e = L.marker(
#                 [38.757301, -9.369216],
#                 {}
#             ).addTo(map_5acb907c044326aad1c77b0b4523035a);
#
#
#         var popup_ce22a130bbb784a5d8f17f3c39da1121 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9ae6e84d93cd29ccea089ccdcd78128c = $(`&lt;div id=&quot;html_9ae6e84d93cd29ccea089ccdcd78128c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Lissabon&lt;/b&gt;:&lt;br&gt;Receiving plant&lt;/div&gt;`)[0];
#                 popup_ce22a130bbb784a5d8f17f3c39da1121.setContent(html_9ae6e84d93cd29ccea089ccdcd78128c);
#
#
#
#         marker_bff19858cbed71f5efbf0bd966521f8e.bindPopup(popup_ce22a130bbb784a5d8f17f3c39da1121)
#         ;
#
#
#
#
#             var marker_3e7f22c5cd1a0368e6509dd5c49b0244 = L.marker(
#                 [40.57675934, -3.243162431],
#                 {}
#             ).addTo(map_5acb907c044326aad1c77b0b4523035a);
#
#
#         var popup_88604f500f0fe0c84086d97202f9bb79 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ab438df434496af8cc9eeecdfe2d4fb3 = $(`&lt;div id=&quot;html_ab438df434496af8cc9eeecdfe2d4fb3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Alovera&lt;/b&gt;:&lt;br&gt;Receiving plant&lt;/div&gt;`)[0];
#                 popup_88604f500f0fe0c84086d97202f9bb79.setContent(html_ab438df434496af8cc9eeecdfe2d4fb3);
#
#
#
#         marker_3e7f22c5cd1a0368e6509dd5c49b0244.bindPopup(popup_88604f500f0fe0c84086d97202f9bb79)
#         ;
#
#
#
#
#             var marker_0aa8815deb098b710c53ee77752f0c2d = L.marker(
#                 [45.54113003, 9.281575673],
#                 {}
#             ).addTo(map_5acb907c044326aad1c77b0b4523035a);
#
#
#         var popup_f95aa20512c8bcbca15063cc912104e6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fac141df44de9e1473ab0777b8419a75 = $(`&lt;div id=&quot;html_fac141df44de9e1473ab0777b8419a75&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Cologno Monzese&lt;/b&gt;:&lt;br&gt;Receiving plant&lt;/div&gt;`)[0];
#                 popup_f95aa20512c8bcbca15063cc912104e6.setContent(html_fac141df44de9e1473ab0777b8419a75);
#
#
#
#         marker_0aa8815deb098b710c53ee77752f0c2d.bindPopup(popup_f95aa20512c8bcbca15063cc912104e6)
#         ;
#
#
#
#
#             var marker_7a08701e4473d721b3d6d0441693c70b = L.marker(
#                 [45.83747369, 5.261173337],
#                 {}
#             ).addTo(map_5acb907c044326aad1c77b0b4523035a);
#
#
#         var popup_3e5917a48184e52bbdf87f190d089739 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_73d31ca7c4ae9cb807536f6ea4cbcf7b = $(`&lt;div id=&quot;html_73d31ca7c4ae9cb807536f6ea4cbcf7b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Blyes&lt;/b&gt;:&lt;br&gt;Receiving plant&lt;/div&gt;`)[0];
#                 popup_3e5917a48184e52bbdf87f190d089739.setContent(html_73d31ca7c4ae9cb807536f6ea4cbcf7b);
#
#
#
#         marker_7a08701e4473d721b3d6d0441693c70b.bindPopup(popup_3e5917a48184e52bbdf87f190d089739)
#         ;
#
#
#
#
#             var marker_f1822e2520e5b104d35fabce01e3e262 = L.marker(
#                 [51.29525785, 4.928540898],
#                 {}
#             ).addTo(map_5acb907c044326aad1c77b0b4523035a);
#
#
#         var popup_6b7183f07d9f63717064047abde11d5a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_41803a8b4fd61a7c0e28c228496536e4 = $(`&lt;div id=&quot;html_41803a8b4fd61a7c0e28c228496536e4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Turnhout&lt;/b&gt;:&lt;br&gt;Producing plant&lt;/div&gt;`)[0];
#                 popup_6b7183f07d9f63717064047abde11d5a.setContent(html_41803a8b4fd61a7c0e28c228496536e4);
#
#
#
#         marker_f1822e2520e5b104d35fabce01e3e262.bindPopup(popup_6b7183f07d9f63717064047abde11d5a)
#         ;
